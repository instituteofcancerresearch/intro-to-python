# %% [markdown]
# <img src="graphics/icr_logo.png" alt="drawing" width="300"/>
#
# # An introduction to programming with Python
#
# ## Welcome to the course! 👋
#
# _Digital Services > Scientific Computing > __Scientific Software Group___
#
# We are here to support the research offerts of the ICR, by writing software!
#
# ##### Rachel Alcraft
# - Research software engineer at ICR since May 2023
# - Previously *Research Software Engineer* at UCL
# - MScs in Computing & Bioinformatics
#
# ##### Kareem Marzouk
# - Research software engineer at ICR since Oct 2022
# - Previously MPhys/PhD in Theoretical Physics/Cosmology at Sussex
#
# #### Who are you, and why are you interested in learning Python?...
#
# ***
#
# ## Outline for today
#
# - **A-00** Preamble, explain how this course is going to work
#
# - **A-01** Python language syntax
#
# - **A-02** Variables and data types
#
# - **A-03** Basic operations
#
# - **A-04** Containers
#
# - **A-05** Conditional statements
#
# - **A-06** Loops
#
# ***
#
# ## Part 00: Preamble
#
# We are going to deliver the content of this course using **Jupyter notebooks**. Hopefully you have had chance to install anaconda on your computer, as this *should* ensure that you have an environment that is ready to work.
#
# In order to launch "Jupyter Lab" into your browser, you will need to launch a terminal of some sort...
#
# - **Windows users** - Press start and search for *anaconda powershell*
# - **MacOS users** - Press cmd and search for *terminal*
#
# If anaconda has been installed successfully, after launching your terminal, you should be able to run the command
#
# ```
# jupyter lab
# ```
#
# This should print some information to your terminal before spinning up in your browser... We'll have a walk around now to make sure everyone is OK.
#
# ### Basic cell operations
#
# Jupyter notebooks are **a collection of cells which can contain text, code and plots.**
#
# It is important to understand how to insert, delete, copy, cut & paste cells. To perform any of these operations, first click to the left of a cell then...
#
# - `a` will **insert** a new cell directly above the current selection;
# - `b` will **insert** a new cell directly below the current selection;
# - `dd` will **delete** the current selection;
# - `c` will **copy** the current selection;
# - `x` will **cut** the current selection;
# - `v` will **paste** a cell in the "clipboard" directly below the current selection;
#
# ***
#
# ⚙️ ***Exercise:***
# - Try inserting a new cell below this cell, then deleting it.
#
# ***

# %% [markdown]
# To "run" a cell, you can click to the left of a cell containing a code, then press `ctrl+enter`. Alternatively you can click on the "play" button at the top of the window.
#
# ***
#
# ⚙️ ***Exercise:***
# - Try running the cell below
#
# ***

# %%
2 ** 3

# %% [markdown]
# Any output that is generated by some code within a notebook environment will be stored below the cell that has been run.
#
# This, in combination with the ability to write textual information, are properties that make jupyter notebooks a popular choice for performing scientific analyses.

# %% [markdown]
# #### Writing text and using Markdown
#
# By default, when a new cell has been created, it is of `code` type. You can change this to a `text` type, more precisely known as `markdown`, from the drop-down selection next to the "fast-forward" button at the top of the notebook page.
#
# ***
#
# ⚙️ ***Exercise:***
# 1. Create a new cell
# 2. Switch it to "Markdown"
# 3. Add some text
# 4. Run the cell as you did for code content earlier
#
# ***
#
# Markdown enables you to do lots of simple and clean text formatting. We don't want to get too bogged down with those details in this course, but you can have a look at [this link](https://www.markdownguide.org/basic-syntax/) for a great overview.

# %% [markdown]
# #### Jupyter notebooks: basic cell operations
#
# You can create, save and open notebooks via the `File` button in the top left corner of the notebook window, and make use of standard hotkeys for handling files (`ctrl+s`, `ctrl+o`, etc).
#
# Once you are ready, **open the next notebook** for this course "notes-01-language-syntax.ipynb".
